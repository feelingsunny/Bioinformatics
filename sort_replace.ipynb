# %% [markdown]
# <a href="https://colab.research.google.com/github/feelingsunny/Bioinformatics/blob/master/sort_replace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import numpy

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/open?id=1Jq-dBjzknyEPD2eatreADkMP_emKNlsx' # The shareable link

# %%
fluff, id = link.split('=')
print (id) # Verify that you have everything after '='
# Out:
# 1Jq-dBjzknyEPD2eatreADkMP_emKNlsx

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('PathwayCommons11.All.hgnc.csv')  
df = pd.read_csv('PathwayCommons11.All.hgnc.csv', header = None, delimiter='\t')
# Dataset is now stored in a Pandas Dataframe

# %%
df
# Out:
#               0                            1            2
# 0          A1BG       controls-expression-of          A2M
# 1          A1BG               interacts-with        ABCC6
# 2          A1BG               interacts-with         ACE2
# 3          A1BG               interacts-with       ADAM10
# 4          A1BG               interacts-with       ADAM17
# 5          A1BG               interacts-with        ADAM9
# 6          A1BG               interacts-with         AGO1
# 7          A1BG  controls-phosphorylation-of         AKT1
# 8          A1BG     controls-state-change-of         AKT1
# 9          A1BG               interacts-with        ANXA7
# 10         A1BG               interacts-with       CDKN1A
# 11         A1BG               interacts-with       CRISP3
# 12         A1BG               interacts-with          CRK
# 13         A1BG               interacts-with        CSE1L
# 14         A1BG               interacts-with        CUL4B
# 15         A1BG               interacts-with        DDX3X
# 16         A1BG               interacts-with        DEAF1
# 17         A1BG               interacts-with         E2F1
# 18         A1BG               interacts-with         E2F2
# 19         A1BG               interacts-with         E2F3
# 20         A1BG               interacts-with        EIF3E
# 21         A1BG               interacts-with       ELAVL1
# 22         A1BG               interacts-with         FDXR
# 23         A1BG               interacts-with       GABRA2
# 24         A1BG               interacts-with        GDPD1
# 25         A1BG               interacts-with       GLIPR1
# 26         A1BG              in-complex-with         GRB2
# 27         A1BG               interacts-with         GRB7
# 28         A1BG               interacts-with        HNF4A
# 29         A1BG               interacts-with       HNRNPC
# ...         ...                          ...          ...
# 1850977  ZSWIM8     controls-state-change-of        ROBO3
# 1850978  ZSWIM8               interacts-with         ZUP1
# 1850979    ZW10     controls-state-change-of       DIAPH2
# 1850980    ZW10     controls-state-change-of        STAG2
# 1850981    ZW10              in-complex-with       ZWILCH
# 1850982    ZW10               interacts-with       ZWILCH
# 1850983    ZW10              in-complex-with        ZWINT
# 1850984    ZW10               interacts-with        ZWINT
# 1850985  ZWILCH     controls-state-change-of       DIAPH2
# 1850986  ZWILCH     controls-state-change-of        STAG2
# 1850987  ZWILCH              in-complex-with        ZWINT
# 1850988   ZWINT     controls-state-change-of       DIAPH2
# 1850989   ZWINT     controls-state-change-of        STAG2
# 1850990    ZXDA               interacts-with         ZXDC
# 1850991     ZYX     controls-state-change-of         VASP
# 1850992     ZYX        controls-transport-of         VASP
# 1850993    ZZZ3       controls-production-of  CHEBI:15346
# 1850994    ZZZ3     controls-state-change-of     HIST1H3A
# 1850995    ZZZ3     controls-state-change-of     HIST1H3B
# 1850996    ZZZ3     controls-state-change-of     HIST1H3C
# 1850997    ZZZ3     controls-state-change-of     HIST1H3D
# 1850998    ZZZ3     controls-state-change-of     HIST1H3E
# 1850999    ZZZ3     controls-state-change-of     HIST1H3F
# 1851000    ZZZ3     controls-state-change-of     HIST1H3G
# 1851001    ZZZ3     controls-state-change-of     HIST1H3H
# 1851002    ZZZ3     controls-state-change-of     HIST1H3I
# 1851003    ZZZ3     controls-state-change-of     HIST1H3J
# 1851004    ZZZ3     controls-state-change-of     HIST2H3A
# 1851005    ZZZ3     controls-state-change-of     HIST2H3C
# 1851006    ZZZ3     controls-state-change-of     HIST2H3D
#
# [1851007 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851007 entries, 0 to 1851006
# Data columns (total 3 columns):
# 0    object
# 1    object
# 2    object
# dtypes: object(3)
# memory usage: 42.4+ MB

# %%
df1=df.replace({'controls-state-change-of':'SR',
            'controls-phosphorylation-of':'SRp',
            'controls-expression-of':'ER',
            'in-complex-with': 'CAI',
            'controls-transport-of':'TR',
            'controls-transport-of-chemical':'TRc',
            'chemical-affects':'ca',
            'interacts-with':'MI',
            'used-to-produce':'sp',
            'consumption-controlled-by':'sE',
            'controls-production-of':'Ep',
            'catalysis-precedes':'EF',
            'reacts-with':'rw'
      })
df1
# Out:
#               0    1            2
# 0          A1BG   ER          A2M
# 1          A1BG   MI        ABCC6
# 2          A1BG   MI         ACE2
# 3          A1BG   MI       ADAM10
# 4          A1BG   MI       ADAM17
# 5          A1BG   MI        ADAM9
# 6          A1BG   MI         AGO1
# 7          A1BG  SRp         AKT1
# 8          A1BG   SR         AKT1
# 9          A1BG   MI        ANXA7
# 10         A1BG   MI       CDKN1A
# 11         A1BG   MI       CRISP3
# 12         A1BG   MI          CRK
# 13         A1BG   MI        CSE1L
# 14         A1BG   MI        CUL4B
# 15         A1BG   MI        DDX3X
# 16         A1BG   MI        DEAF1
# 17         A1BG   MI         E2F1
# 18         A1BG   MI         E2F2
# 19         A1BG   MI         E2F3
# 20         A1BG   MI        EIF3E
# 21         A1BG   MI       ELAVL1
# 22         A1BG   MI         FDXR
# 23         A1BG   MI       GABRA2
# 24         A1BG   MI        GDPD1
# 25         A1BG   MI       GLIPR1
# 26         A1BG  CAI         GRB2
# 27         A1BG   MI         GRB7
# 28         A1BG   MI        HNF4A
# 29         A1BG   MI       HNRNPC
# ...         ...  ...          ...
# 1850977  ZSWIM8   SR        ROBO3
# 1850978  ZSWIM8   MI         ZUP1
# 1850979    ZW10   SR       DIAPH2
# 1850980    ZW10   SR        STAG2
# 1850981    ZW10  CAI       ZWILCH
# 1850982    ZW10   MI       ZWILCH
# 1850983    ZW10  CAI        ZWINT
# 1850984    ZW10   MI        ZWINT
# 1850985  ZWILCH   SR       DIAPH2
# 1850986  ZWILCH   SR        STAG2
# 1850987  ZWILCH  CAI        ZWINT
# 1850988   ZWINT   SR       DIAPH2
# 1850989   ZWINT   SR        STAG2
# 1850990    ZXDA   MI         ZXDC
# 1850991     ZYX   SR         VASP
# 1850992     ZYX   TR         VASP
# 1850993    ZZZ3   Ep  CHEBI:15346
# 1850994    ZZZ3   SR     HIST1H3A
# 1850995    ZZZ3   SR     HIST1H3B
# 1850996    ZZZ3   SR     HIST1H3C
# 1850997    ZZZ3   SR     HIST1H3D
# 1850998    ZZZ3   SR     HIST1H3E
# 1850999    ZZZ3   SR     HIST1H3F
# 1851000    ZZZ3   SR     HIST1H3G
# 1851001    ZZZ3   SR     HIST1H3H
# 1851002    ZZZ3   SR     HIST1H3I
# 1851003    ZZZ3   SR     HIST1H3J
# 1851004    ZZZ3   SR     HIST2H3A
# 1851005    ZZZ3   SR     HIST2H3C
# 1851006    ZZZ3   SR     HIST2H3D
#
# [1851007 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851007 entries, 0 to 1851006
# Data columns (total 3 columns):
# 0    object
# 1    object
# 2    object
# dtypes: object(3)
# memory usage: 42.4+ MB

# %%
df1.describe()
# Out:
#                   0        1        2
# count       1851007  1851007  1851007
# unique        27344       13    23470
# top     CHEBI:39867       ca     TP53
# freq          14084   607820     2844
